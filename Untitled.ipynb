# %%
# !pip install perlin-noise
# !pip install --upgrade numpy
# !pip install --upgrade matplotlib seaborn perlin_noise
# !pip install --upgrade pandas
# Out:
# Requirement already satisfied: numpy in c:\users\darkc\anaconda3\lib\site-packages (2.0.2)
# Requirement already satisfied: matplotlib in c:\users\darkc\anaconda3\lib\site-packages (3.9.4)
# Requirement already satisfied: seaborn in c:\users\darkc\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: perlin_noise in c:\users\darkc\anaconda3\lib\site-packages (1.13)
# Requirement already satisfied: packaging>=20.0 in c:\users\darkc\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\darkc\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\darkc\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\darkc\anaconda3\lib\site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: numpy>=1.23 in c:\users\darkc\anaconda3\lib\site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\darkc\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\darkc\anaconda3\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\darkc\anaconda3\lib\site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\darkc\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pillow>=8 in c:\users\darkc\anaconda3\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\darkc\anaconda3\lib\site-packages (from seaborn) (1.4.4)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\darkc\anaconda3\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.8.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\darkc\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\darkc\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: pandas in c:\users\darkc\anaconda3\lib\site-packages (1.4.4)
# Collecting pandas
#   Downloading pandas-2.2.3-cp39-cp39-win_amd64.whl (11.6 MB)
#      ---------------------------------------- 11.6/11.6 MB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: tzdata>=2022.7 in c:\users\darkc\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\darkc\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\darkc\anaconda3\lib\site-packages (from pandas) (2.0.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\darkc\anaconda3\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\darkc\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.4.4
#     Uninstalling pandas-1.4.4:
#       Successfully uninstalled pandas-1.4.4
# Successfully installed pandas-2.2.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dash-tools 1.11.1 requires packaging==21.0, but you have packaging 24.1 which is incompatible.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from perlin_noise import PerlinNoise

# Define grid size
size = 50

# Initialize Perlin Noise
noise = PerlinNoise(octaves=4, seed=42)

# Generate elevation data using Perlin noise
elevation = np.zeros((size, size))
for i in range(size):
    for j in range(size):
        elevation[i, j] = noise([i / size, j / size])

# Normalize elevation values to range 0-100
elevation = (elevation - np.min(elevation)) / (np.max(elevation) - np.min(elevation)) * 100

# Convert to Pandas DataFrame for display
df = pd.DataFrame(elevation.round(1))

# %%
# Plot the elevation data as a heatmap
fig, ax = plt.subplots(figsize=(10, 10))
ax.axis("tight")
ax.axis("off")

# Create a table displaying the elevation values
table = ax.table(cellText=df.values, 
                 colLabels=[f"X{i}" for i in range(size)], 
                 rowLabels=[f"Y{i}" for i in range(size)], 
                 cellLoc="center", 
                 loc="center")

# Adjust table font size for readability
table.auto_set_font_size(False)
table.set_fontsize(6)

plt.show()

# %%
# Generate coordinate grids for contour plot
X, Y = np.meshgrid(np.arange(size), np.arange(size))

# %%
# Version 1: Grid with Elevation Values (using imshow to match contour orientation)
plt.figure(figsize=(15, 15))
plt.imshow(elevation, cmap='terrain', origin='lower', aspect='auto')
plt.colorbar(label="Elevation")
plt.title("Randomized Elevation Grid (Perlin Noise)")
plt.xlabel("X Coordinate")
plt.ylabel("Y Coordinate")
plt.show()

# %%
# Version 2: Contour Map with Elevation Lines (Same Data)
plt.figure(figsize=(15, 12))
plt.contour(X, Y, elevation, levels=25, cmap='terrain')
plt.colorbar(label="Elevation")
plt.title("Randomized Elevation Contour Lines (Perlin Noise)")
plt.xlabel("X Coordinate")
plt.ylabel("Y Coordinate")
plt.show()
